# %%
import pandas as pd 
import numpy as np

# %%
df=pd.read_csv("employee_sample_dataset.csv")

# %%
df.head(30)
# Out:
#     EmployeeID             Name   Age        City   Department      Salary  \
# 0         85.0         Sara Ali  50.0    peshawar      Finance    37654.70
# 1          NaN              NaN   NaN         NaN          NaN         NaN
# 2        299.0        Ali Javed  32.0      multan           HR    96309.61
# 3        288.0        Noor Raza  28.0       Pindi      Finance    87658.83
# 4        100.0         Ali Shah  16.0    peshawar    Marketing    48996.14
# 5        276.0      Faisal Raza  42.0       Pindi  Engineering    57324.44
# 6        142.0        Zara Butt  40.0      LAHORE    Marketing    38797.37
# 7        119.0      Omar Ansari  34.0   islamabad      Support    72397.14
# 8          NaN              NaN   NaN         NaN          NaN         NaN
# 9         31.0      Ayesha Baig  25.0   islamabad           HR    64964.86
# 10       123.0   Tariq Chaudhry  31.0  Faisalabad           HR         NaN
# ...

# %% [markdown]
# Check the duplicate row

# %%
df[df.duplicated()]
# Out:
#      EmployeeID            Name   Age        City   Department      Salary  \
# 8           NaN             NaN   NaN         NaN          NaN         NaN
# 31        177.0    Usman Ansari  29.0      Quetta           HR    28961.58
# 90         74.0       Iqra Raza  24.0  rawalpindi      Support    64740.69
# 94        123.0  Tariq Chaudhry  31.0  Faisalabad           HR         NaN
# 107       300.0     Fatima Shah  41.0      multan        Sales  3066568.00
# 109         NaN             NaN   NaN         NaN          NaN         NaN
# 157       267.0       Omar Shah  33.0      multan      Finance    71320.33
# 189       214.0      Faisal Ali   NaN  rawalpindi  engineering    76912.41
# 190       128.0      Omar Javed  36.0      LAHORE  Engineering    92450.83
# 196         NaN             NaN   NaN         NaN          NaN         NaN
# 208       107.0     Bilal Javed  30.0       Pindi        Sales    86766.34
# ...

# %%
df=df.drop_duplicates()

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [EmployeeID, Name, Age, City, Department, Salary, JoinDate, Email, PerformanceRating]
# Index: []

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 301 entries, 0 to 319
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   EmployeeID         300 non-null    float64
#  1   Name               300 non-null    str
#  2   Age                279 non-null    float64
#  3   City               300 non-null    str
#  4   Department         300 non-null    str
#  5   Salary             282 non-null    float64
#  6   JoinDate           292 non-null    str
#  7   Email              295 non-null    str
#  8   PerformanceRating  300 non-null    float64
# dtypes: float64(4), str(5)
# memory usage: 23.5 KB

# %%
df
# Out:
#      EmployeeID          Name    Age        City Department    Salary  \
# 0          85.0      Sara Ali   50.0    peshawar    Finance  37654.70
# 1           NaN           NaN    NaN         NaN        NaN       NaN
# 2         299.0     Ali Javed   32.0      multan         HR  96309.61
# 3         288.0     Noor Raza   28.0       Pindi    Finance  87658.83
# 4         100.0      Ali Shah   16.0    peshawar  Marketing  48996.14
# ..          ...           ...    ...         ...        ...       ...
# 315       212.0    Omar Malik   40.0     karachi      Sales  58129.10
# 316        68.0  Usman Ansari   39.0     karachi  Marketing  70208.11
# 317        26.0   Faisal Awan   43.0  faisalabad    Support  81763.63
# 318       197.0  Omar Qureshi  999.0      Multan      Sales  86411.97
# 319       176.0    Hina Javed   26.0   islamabad  Marketing  86590.09
#
#         JoinDate                     Email  PerformanceRating
# 0     2022-04-03      sara.ali@example.com                2.1
# ...

# %%
df[df['EmployeeID']==1000]
# Out:
# Empty DataFrame
# Columns: [EmployeeID, Name, Age, City, Department, Salary, JoinDate, Email, PerformanceRating]
# Index: []

# %%
df['EmployeeID'].max()
# Out:
# np.float64(300.0)

# %%
next_id = int(df['EmployeeID'].max()) + 1

for idx in df[df['EmployeeID'].isna()].index:
    df.loc[idx, 'EmployeeID'] = next_id
    next_id += 1

# %% [markdown]
# Sussessfully mange the thr null and duplicate value

# %%
df['EmployeeID']=df['EmployeeID'].astype(int)

# %%
print(type(df))
# Out:
# <class 'pandas.DataFrame'>

# %%
df=df.set_index('EmployeeID')

# %%
df
# Out:
#                     Name    Age        City Department    Salary     JoinDate  \
# EmployeeID
# 85              Sara Ali   50.0    peshawar    Finance  37654.70   2022-04-03
# 301                  NaN    NaN         NaN        NaN       NaN          NaN
# 299            Ali Javed   32.0      multan         HR  96309.61  11-Jul-2020
# 288            Noor Raza   28.0       Pindi    Finance  87658.83   25/03/2022
# 100             Ali Shah   16.0    peshawar  Marketing  48996.14   10-15-2021
# ...                  ...    ...         ...        ...       ...          ...
# 212           Omar Malik   40.0     karachi      Sales  58129.10  30-Jun-2022
# 68          Usman Ansari   39.0     karachi  Marketing  70208.11   30/04/2024
# 26           Faisal Awan   43.0  faisalabad    Support  81763.63   28/02/2023
# 197         Omar Qureshi  999.0      Multan      Sales  86411.97   08-24-2021
# 176           Hina Javed   26.0   islamabad  Marketing  86590.09   2022-02-27
#
# ...

# %%
df.rename(columns={'EmployeeID':'Employee_ID','JoinDate':'Join_Date','PerformanceRating':'Performance_Rating'})
# Out:
#                     Name    Age        City Department    Salary    Join_Date  \
# EmployeeID
# 85              Sara Ali   50.0    peshawar    Finance  37654.70   2022-04-03
# 301                  NaN    NaN         NaN        NaN       NaN          NaN
# 299            Ali Javed   32.0      multan         HR  96309.61  11-Jul-2020
# 288            Noor Raza   28.0       Pindi    Finance  87658.83   25/03/2022
# 100             Ali Shah   16.0    peshawar  Marketing  48996.14   10-15-2021
# ...                  ...    ...         ...        ...       ...          ...
# 212           Omar Malik   40.0     karachi      Sales  58129.10  30-Jun-2022
# 68          Usman Ansari   39.0     karachi  Marketing  70208.11   30/04/2024
# 26           Faisal Awan   43.0  faisalabad    Support  81763.63   28/02/2023
# 197         Omar Qureshi  999.0      Multan      Sales  86411.97   08-24-2021
# 176           Hina Javed   26.0   islamabad  Marketing  86590.09   2022-02-27
#
# ...

# %%
df = df.rename_axis("Employee_ID")

# %%
df
# Out:
#                      Name    Age        City Department    Salary  \
# Employee_ID
# 85               Sara Ali   50.0    peshawar    Finance  37654.70
# 301                   NaN    NaN         NaN        NaN       NaN
# 299             Ali Javed   32.0      multan         HR  96309.61
# 288             Noor Raza   28.0       Pindi    Finance  87658.83
# 100              Ali Shah   16.0    peshawar  Marketing  48996.14
# ...                   ...    ...         ...        ...       ...
# 212            Omar Malik   40.0     karachi      Sales  58129.10
# 68           Usman Ansari   39.0     karachi  Marketing  70208.11
# 26            Faisal Awan   43.0  faisalabad    Support  81763.63
# 197          Omar Qureshi  999.0      Multan      Sales  86411.97
# 176            Hina Javed   26.0   islamabad  Marketing  86590.09
#
#                 JoinDate                     Email  PerformanceRating
# Employee_ID
# 85            2022-04-03      sara.ali@example.com                2.1
# ...

# %%
df = df.sort_index()

# %%
df
# Out:
#                       Name   Age        City   Department      Salary  \
# Employee_ID
# 1              Ayesha Khan  35.0      Multan        Sales    72234.71
# 2              Iqra Ansari  23.0  faisalabad      Support  4068902.00
# 3            Hina Siddiqui  44.0      Multan      Finance    90348.69
# 4             Mariam Malik  27.0  Faisalabad  Engineering    64496.60
# 5            Faisal Farooq  33.0         FSD  Engineering    36734.40
# ...                    ...   ...         ...          ...         ...
# 297            Kamran Butt   NaN    peshawar           HR    78931.10
# 298           Hamza Ansari  38.0  rawalpindi    Marketing    80660.64
# 299              Ali Javed  32.0      multan           HR    96309.61
# 300            Fatima Shah  41.0      multan        Sales  3066568.00
# 301                    NaN   NaN         NaN          NaN         NaN
#
#                 JoinDate                      Email  PerformanceRating
# Employee_ID
# ...

# %%
df.describe()
# Out:
#               Age        Salary  PerformanceRating
# count  279.000000  2.820000e+02          300.00000
# mean    38.426523  1.988461e+05            3.19900
# std     82.873272  6.733932e+05            1.81774
# min     -5.000000  2.018090e+04            1.00000
# 25%     26.000000  6.653740e+04            2.00000
# 50%     31.000000  7.895114e+04            3.00000
# 75%     36.000000  9.406522e+04            4.20000
# max    999.000000  4.722554e+06           11.50000

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 301 entries, 1 to 301
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               300 non-null    str
#  1   Age                279 non-null    float64
#  2   City               300 non-null    str
#  3   Department         300 non-null    str
#  4   Salary             282 non-null    float64
#  5   JoinDate           292 non-null    str
#  6   Email              295 non-null    str
#  7   PerformanceRating  300 non-null    float64
# dtypes: float64(3), str(5)
# memory usage: 21.2 KB

# %%
df['Department'].value_counts()
# Out:
# Department
# Finance        56
# Support        55
# Sales          49
# HR             48
# Marketing      46
# Engineering    31
# engineering     4
# finance         4
# sales           3
# support         3
# hr              1
# Name: count, dtype: int64

# %%
df['Department']=df['Department'].replace({'sales':'Sales','hr':'HR','finance':'Finance','engineering':'Engineering','support':'Support'})

# %%
df['Department'].value_counts()
# Out:
# Department
# Finance        60
# Support        58
# Sales          49
# HR             49
# Marketing      46
# Engineering    35
# Sales           3
# Name: count, dtype: int64

# %%
df['Department']=df['Department'].replace({'Sales ':'Sales'})

# %%
df['Department'].value_counts()
# Out:
# Department
# Finance        60
# Support        58
# Sales          52
# HR             49
# Marketing      46
# Engineering    35
# Name: count, dtype: int64

# %%
df['Department'].isnull().sum()
# Out:
# np.int64(1)

# %%
df['Department'] = df['Department'].fillna(df['Department'].mode()[0])

# %% [markdown]
# Now Successfully implmented the EDA in Department column

# %%
df
# Out:
#                       Name   Age        City   Department      Salary  \
# Employee_ID
# 1              Ayesha Khan  35.0      Multan        Sales    72234.71
# 2              Iqra Ansari  23.0  faisalabad      Support  4068902.00
# 3            Hina Siddiqui  44.0      Multan      Finance    90348.69
# 4             Mariam Malik  27.0  Faisalabad  Engineering    64496.60
# 5            Faisal Farooq  33.0         FSD  Engineering    36734.40
# ...                    ...   ...         ...          ...         ...
# 297            Kamran Butt   NaN    peshawar           HR    78931.10
# 298           Hamza Ansari  38.0  rawalpindi    Marketing    80660.64
# 299              Ali Javed  32.0      multan           HR    96309.61
# 300            Fatima Shah  41.0      multan        Sales  3066568.00
# 301                    NaN   NaN         NaN      Finance         NaN
#
#                 JoinDate                      Email  PerformanceRating
# Employee_ID
# ...

# %%
df['Name'].isnull().sum()
# Out:
# np.int64(1)

# %%
df['Name'] = df['Name'].fillna(df['Name'].mode()[0])

# %% [markdown]
# Now Successfully implmented the EDA in Name column

# %%
df
# Out:
#                       Name   Age        City   Department      Salary  \
# Employee_ID
# 1              Ayesha Khan  35.0      Multan        Sales    72234.71
# 2              Iqra Ansari  23.0  faisalabad      Support  4068902.00
# 3            Hina Siddiqui  44.0      Multan      Finance    90348.69
# 4             Mariam Malik  27.0  Faisalabad  Engineering    64496.60
# 5            Faisal Farooq  33.0         FSD  Engineering    36734.40
# ...                    ...   ...         ...          ...         ...
# 297            Kamran Butt   NaN    peshawar           HR    78931.10
# 298           Hamza Ansari  38.0  rawalpindi    Marketing    80660.64
# 299              Ali Javed  32.0      multan           HR    96309.61
# 300            Fatima Shah  41.0      multan        Sales  3066568.00
# 301              Sana Baig   NaN         NaN      Finance         NaN
#
#                 JoinDate                      Email  PerformanceRating
# Employee_ID
# ...

# %%
df['Age']=df['Age'].fillna(df['Age'].mean())

df['Age'] = df['Age'].astype(int)

# %%
df
# Out:
#                       Name  Age        City   Department      Salary  \
# Employee_ID
# 1              Ayesha Khan   35      Multan        Sales    72234.71
# 2              Iqra Ansari   23  faisalabad      Support  4068902.00
# 3            Hina Siddiqui   44      Multan      Finance    90348.69
# 4             Mariam Malik   27  Faisalabad  Engineering    64496.60
# 5            Faisal Farooq   33         FSD  Engineering    36734.40
# ...                    ...  ...         ...          ...         ...
# 297            Kamran Butt   38    peshawar           HR    78931.10
# 298           Hamza Ansari   38  rawalpindi    Marketing    80660.64
# 299              Ali Javed   32      multan           HR    96309.61
# 300            Fatima Shah   41      multan        Sales  3066568.00
# 301              Sana Baig   38         NaN      Finance         NaN
#
#                 JoinDate                      Email  PerformanceRating
# Employee_ID
# ...

# %% [markdown]
# Successfully implmented the EDA in Age col

# %%
df['City'].value_counts()
# Out:
# City
# Peshawar      25
# Multan        21
# Quetta        19
# rawalpindi    19
# peshawar      19
# Pindi         17
# Isl'abad      16
# karachi       16
# quetta        15
# FSD           14
# multan        14
# Rawalpindi    13
# Islamabad     13
# faisalabad    12
# islamabad     11
# Faisalabad    10
# lahore         9
# KARACHI        9
# LAHORE         9
# Lahore         9
# Karachi        5
# Lahore         5
# Name: count, dtype: int64

# %%
df['City']=df['City'].replace({'peshawar':'Peshawar','multan':'Multan','quetta':'Quetta','rawalpindi':'Rawalpindi','Pindi':'Rawalpindi','islamabad':'Islamabad','karachi':'Karachi','FSD':'Faisalabad','faisalabad':'Faisalabad','KARACHI':'Karachi','LAHORE':'Lahore','lahore':'Lahore'})

# %%
df['City'].value_counts()
# Out:
# City
# Rawalpindi    49
# Peshawar      44
# Islamabad     40
# Faisalabad    36
# Multan        35
# Quetta        34
# Karachi       30
# Lahore        27
# Lahore         5
# Name: count, dtype: int64

# %%
df['City'] = df['City'].replace("Isl'abad", "Islamabad")

# %%
df['City'].value_counts()
# Out:
# City
# Rawalpindi    49
# Peshawar      44
# Islamabad     40
# Faisalabad    36
# Multan        35
# Quetta        34
# Karachi       30
# Lahore        27
# Lahore         5
# Name: count, dtype: int64

# %%
df['City'] = df['City'].str.strip()

# %%
df['City'].value_counts()
# Out:
# City
# Rawalpindi    49
# Peshawar      44
# Islamabad     40
# Faisalabad    36
# Multan        35
# Quetta        34
# Lahore        32
# Karachi       30
# Name: count, dtype: int64

# %%
df
# Out:
#                       Name  Age        City   Department      Salary  \
# Employee_ID
# 1              Ayesha Khan   35      Multan        Sales    72234.71
# 2              Iqra Ansari   23  Faisalabad      Support  4068902.00
# 3            Hina Siddiqui   44      Multan      Finance    90348.69
# 4             Mariam Malik   27  Faisalabad  Engineering    64496.60
# 5            Faisal Farooq   33  Faisalabad  Engineering    36734.40
# ...                    ...  ...         ...          ...         ...
# 297            Kamran Butt   38    Peshawar           HR    78931.10
# 298           Hamza Ansari   38  Rawalpindi    Marketing    80660.64
# 299              Ali Javed   32      Multan           HR    96309.61
# 300            Fatima Shah   41      Multan        Sales  3066568.00
# 301              Sana Baig   38         NaN      Finance         NaN
#
#                 JoinDate                      Email  PerformanceRating
# Employee_ID
# ...

# %% [markdown]
# Successfull implement the EDA in City column

# %%
df['Email'] = df['Email'].fillna(df['Email'].mode()[0])
df['JoinDate'] = df['JoinDate'].fillna(df['JoinDate'].mode()[0])

# %%
df=df.rename(columns={'EmployeeID':'Employee_ID','JoinDate':'Join_Date','PerformanceRating':'Performance_Rating'})

# %%
df
# Out:
#                       Name  Age        City   Department      Salary  \
# Employee_ID
# 1              Ayesha Khan   35      Multan        Sales    72234.71
# 2              Iqra Ansari   23  Faisalabad      Support  4068902.00
# 3            Hina Siddiqui   44      Multan      Finance    90348.69
# 4             Mariam Malik   27  Faisalabad  Engineering    64496.60
# 5            Faisal Farooq   33  Faisalabad  Engineering    36734.40
# ...                    ...  ...         ...          ...         ...
# 297            Kamran Butt   38    Peshawar           HR    78931.10
# 298           Hamza Ansari   38  Rawalpindi    Marketing    80660.64
# 299              Ali Javed   32      Multan           HR    96309.61
# 300            Fatima Shah   41      Multan        Sales  3066568.00
# 301              Sana Baig   38         NaN      Finance         NaN
#
#                Join_Date                      Email  Performance_Rating
# Employee_ID
# ...

# %%
df['Join_Date'] = pd.to_datetime(df['Join_Date'], format='mixed', dayfirst=True)

# %%
df
# Out:
#                       Name  Age        City   Department      Salary  \
# Employee_ID
# 1              Ayesha Khan   35      Multan        Sales    72234.71
# 2              Iqra Ansari   23  Faisalabad      Support  4068902.00
# 3            Hina Siddiqui   44      Multan      Finance    90348.69
# 4             Mariam Malik   27  Faisalabad  Engineering    64496.60
# 5            Faisal Farooq   33  Faisalabad  Engineering    36734.40
# ...                    ...  ...         ...          ...         ...
# 297            Kamran Butt   38    Peshawar           HR    78931.10
# 298           Hamza Ansari   38  Rawalpindi    Marketing    80660.64
# 299              Ali Javed   32      Multan           HR    96309.61
# 300            Fatima Shah   41      Multan        Sales  3066568.00
# 301              Sana Baig   38         NaN      Finance         NaN
#
#              Join_Date                      Email  Performance_Rating
# Employee_ID
# ...

# %%
df['Email'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['Email']=df['Email'].str.lower()

# %%
df
# Out:
#                       Name  Age        City   Department      Salary  \
# Employee_ID
# 1              Ayesha Khan   35      Multan        Sales    72234.71
# 2              Iqra Ansari   23  Faisalabad      Support  4068902.00
# 3            Hina Siddiqui   44      Multan      Finance    90348.69
# 4             Mariam Malik   27  Faisalabad  Engineering    64496.60
# 5            Faisal Farooq   33  Faisalabad  Engineering    36734.40
# ...                    ...  ...         ...          ...         ...
# 297            Kamran Butt   38    Peshawar           HR    78931.10
# 298           Hamza Ansari   38  Rawalpindi    Marketing    80660.64
# 299              Ali Javed   32      Multan           HR    96309.61
# 300            Fatima Shah   41      Multan        Sales  3066568.00
# 301              Sana Baig   38         NaN      Finance         NaN
#
#              Join_Date                      Email  Performance_Rating
# Employee_ID
# ...

# %%
Q1 = df['Salary'].quantile(0.25)
Q3 = df['Salary'].quantile(0.75)

IQR = Q3 - Q1

lower_limit = Q1 - 1.5 * IQR
upper_limit = Q3 + 1.5 * IQR

salary_outliers = df[(df['Salary'] < lower_limit) | (df['Salary'] > upper_limit)]

salary_outliers
# Out:
#                       Name  Age        City Department      Salary  Join_Date  \
# Employee_ID
# 2              Iqra Ansari   23  Faisalabad    Support  4068902.00 2020-07-23
# 8              Iqra Farooq   26    Peshawar    Support  4347720.50 2021-10-22
# 81              Hina Malik   38  Rawalpindi    Finance   152054.63 2021-04-08
# 173               Omar Ali   47      Lahore  Marketing  3785263.50 2019-01-02
# 193              Zara Shah   30      Quetta  Marketing  2842436.50 2023-08-14
# 198            Zara Farooq   34      Lahore  Marketing    20180.90 2022-04-28
# 205             Zara Iqbal   38      Quetta      Sales  3146015.00 2019-12-15
# 240              Sana Baig   23    Peshawar      Sales  4266669.50 2019-01-01
# 246           Kamran Javed   43    Peshawar    Support    21812.97 2022-12-25
# 283          Zara Chaudhry   37    Peshawar  Marketing  4722554.50 2021-03-28
# 285            Ayesha Shah   31     Karachi      Sales  4370672.00 2021-01-30
# ...

# %%
len(salary_outliers)
# Out:
# 12

# %%
df = df[(df['Salary'] >= lower_limit) & (df['Salary'] <= upper_limit)]

# %%
df['Salary'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['Performance_Rating'].isnull().sum()
# Out:
# np.int64(0)

# %%
df.shape
# Out:
# (270, 8)

# %%
df.to_csv("Updated_Employee_Data.csv", index=False)
